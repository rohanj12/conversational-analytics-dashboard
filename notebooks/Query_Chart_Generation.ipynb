# %%
import os
import pandas as pd
print(os.getcwd())
# Out:
# /Users/rohanjairam

# %%
# %cd /Users/rohanjairam/projects/conversational-analytics-dashboard
# Out:
# /Users/rohanjairam/projects/conversational-analytics-dashboard

# %%
print(os.getcwd())
# Out:
# /Users/rohanjairam/projects/conversational-analytics-dashboard

# %%
from src.chart_generation import generate_chart_from_query

# %%
path = os.getcwd()

# %%
df = pd.read_csv('/Users/rohanjairam/projects/conversational-analytics-dashboard/data/ecommerce.csv', encoding='latin1')

# %%
user_query = "Show me the sales by country"
chart_path = generate_chart_from_query(df, user_query)

# %%
from IPython.display import Image, display

# %%
if chart_path:
    display(Image(filename=chart_path))
else:
    print("No chart was generated for this query.")

# %%
user_query = "Show me the top products in my data"
chart_path = generate_chart_from_query(df, user_query)

# %%
if chart_path:
    display(Image(filename=chart_path))
else:
    print("No chart was generated for this query.")

# %%
user_query = "Generate the unit price distribution"
chart_path = generate_chart_from_query(df, user_query)

# %%
if chart_path:
    display(Image(filename=chart_path))
else:
    print("No chart was generated for this query.")

# %%
user_query = "Finally, show me how I can get the top customers for the respective products"
chart_path = generate_chart_from_query(df, user_query)

# %%
if chart_path:
    display(Image(filename=chart_path))
else:
    print("No chart was generated for this query.")

# %%
user_query = "Generate the monthly sales trend"
chart_path = generate_chart_from_query(df, user_query)

# %%
if chart_path:
    display(Image(filename=chart_path))
else:
    print("No chart was generated for this query.")
